# %%
import pandas as pd
import numpy as np 
from numpy.random import randint
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
randint(-100,100,(5,4))
# Out:
# array([[-13,  59, -60, -63],
#        [  6, -21,  42, -41],
#        [  0, -27,   7, -65],
#        [ 29, -63, -59,  14],
#        [  0,  87,  77, -52]])

# %%
data = randint(-100,100,(5,4))

# %%
data
# Out:
# array([[-60,  60,  77, -99],
#        [ 86,  86, -56, -60],
#        [ 41, -29,  49,  22],
#        [ 49,  72, -17,  13],
#        [-57, -20,  39,  81]])

# %%
np.random.seed(42)
data = randint(-100,100,(5,4))
data
# Out:
# array([[  2,  79,  -8, -86],
#        [  6, -29,  88, -80],
#        [  2,  21, -26, -13],
#        [ 16,  -1,   3,  51],
#        [ 30,  49, -48, -99]])

# %%
columns = ["w","x","y","z"]
index = ["a","b","c","d","e"]

# %%
df = pd.DataFrame(data, index , columns)

# %%
df
# Out:
#     w   x   y   z
# a   2  79  -8 -86
# b   6 -29  88 -80
# c   2  21 -26 -13
# d  16  -1   3  51
# e  30  49 -48 -99

# %%
df["z"]
# Out:
# a   -86
# b   -80
# c   -13
# d    51
# e   -99
# Name: z, dtype: int32

# %%
df["z"].mean()
# Out:
# -45.4

# %% [markdown]
# ### Real Data

# %%
data = pd.read_csv("customer .csv" , sep = "," , encoding = "utf-8")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7000 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            6896 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## EDA

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=penguins, x="flipper_length_mm")

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.displot(data=penguins, x="flipper_length_mm")

# %%
sns.displot(data = data , x = "tenure" )

# %%
sns.displot(data = data , x = "tenure" ,  kind="kde")

# %%
sns.displot(data = data , x = "tenure" ,  kde = True)

# %%
sns.displot(data=data, x="tenure", hue="Churn", kind="kde")

# %%
sns.displot(data=data, x="MonthlyCharges", hue="Churn", kind="kde")

# %%
sns.displot(x=data["MonthlyCharges"], kind="kde")

# %%
data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
sns.displot(data=data, x="MonthlyCharges", hue="Churn", col="gender", kind="kde")

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
sns.displot(data=data, x="MonthlyCharges", hue="Churn", col="Contract", kind="kde", palette="rocket")

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.boxplot(x="gender", y="tenure", data=data)

# %%
plt.figure(figsize = (12,8))
ax = sns.boxplot(x="Contract", y="tenure", hue="Churn",
                 data=data, palette="Set3")

# %%
data = pd.read_csv("customer .csv" , sep = "," , encoding = "utf-8")
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.shape[0]
# Out:
# 7043

# %%
data.shape[1]
# Out:
# 21

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7000 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            6896 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False           True    False       False    True
# 1          False   False           True    False       False   False
# 2          False   False           True    False       False   False
# 3          False   False           True    False       False   False
# 4          False   False           True    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen        43
# Partner               0
# Dependents            0
# tenure              147
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data['tenure'].mean()
# Out:
# 33.04147331786543

# %%
data['tenure'].std()
# Out:
# 24.382259562688727

# %%
data['tenure'].var()
# Out:
# 594.4945813823258

# %%
data['tenure'].mode()
# Out:
# 0    1.0
# Name: tenure, dtype: float64

# %%
data['tenure'].median()
# Out:
# 30.0

# %%
data['tenure'].min()
# Out:
# 1.0

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7000.000000  6896.000000     7043.000000   7043.000000
# mean        0.163143    33.041473       64.761692   2283.300440
# std         0.369522    24.382260       30.090047   2265.000258
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000    10.000000       35.500000    402.225000
# 50%         0.000000    30.000000       70.350000   1400.550000
# 75%         0.000000    56.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %%
sns.distplot(data["TotalCharges"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
data.describe(include = "object")
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
data['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
data.describe(include = "all")
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7000.000000    7043       7043  6896.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.163143     NaN        NaN    33.041473
# std            NaN    NaN       0.369522     NaN        NaN    24.382260
# min            NaN    NaN       0.000000     NaN        NaN     1.000000
# 25%            NaN    NaN       0.000000     NaN        NaN    10.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    30.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    56.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
x = data.describe()
x.style.background_gradient()
# Out:
# <style type="text/css">
# #T_d71ba_row0_col0, #T_d71ba_row0_col1, #T_d71ba_row0_col2, #T_d71ba_row7_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d71ba_row0_col3 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_d71ba_row1_col0, #T_d71ba_row2_col0, #T_d71ba_row2_col1, #T_d71ba_row2_col2, #T_d71ba_row3_col0, #T_d71ba_row3_col1, #T_d71ba_row3_col2, #T_d71ba_row3_col3, #T_d71ba_row4_col0, #T_d71ba_row4_col1, #T_d71ba_row4_col2, #T_d71ba_row5_col0, #T_d71ba_row6_col0, #T_d71ba_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d71ba_row1_col1, #T_d71ba_row1_col2, #T_d71ba_row5_col1, #T_d71ba_row5_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_d71ba_row1_col3, #T_d71ba_row2_col3 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_d71ba_row4_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_d71ba_row5_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# ...

# %%
data.hist(bins = 10 , figsize = (14,12))
plt.show()

# %% [markdown]
# ## slicing

# %%
data.gender
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
data['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %%
data["gender"].count()
# Out:
# 7043

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data[['customerID', 'gender', 'SeniorCitizen', 'Partner']]
# Out:
#       customerID  gender  SeniorCitizen Partner
# 0     7590-VHVEG  Female            NaN     Yes
# 1     5575-GNVDE    Male            NaN      No
# 2     3668-QPYBK    Male            NaN      No
# 3     7795-CFOCW    Male            NaN      No
# 4     9237-HQITU  Female            NaN      No
# ...          ...     ...            ...     ...
# 7038  6840-RESVB    Male            0.0     Yes
# 7039  2234-XADUH  Female            0.0     Yes
# 7040  4801-JZAZL  Female            0.0     Yes
# 7041  8361-LTMKD    Male            1.0     Yes
# 7042  3186-AJIEK    Male            0.0      No
#
# [7043 rows x 4 columns]

# %%
y = data[['customerID', 'gender', 'SeniorCitizen', 'Partner']]
y
# Out:
#       customerID  gender  SeniorCitizen Partner
# 0     7590-VHVEG  Female            NaN     Yes
# 1     5575-GNVDE    Male            NaN      No
# 2     3668-QPYBK    Male            NaN      No
# 3     7795-CFOCW    Male            NaN      No
# 4     9237-HQITU  Female            NaN      No
# ...          ...     ...            ...     ...
# 7038  6840-RESVB    Male            0.0     Yes
# 7039  2234-XADUH  Female            0.0     Yes
# 7040  4801-JZAZL  Female            0.0     Yes
# 7041  8361-LTMKD    Male            1.0     Yes
# 7042  3186-AJIEK    Male            0.0      No
#
# [7043 rows x 4 columns]

# %%
y.to_csv('y.csv')

# %%
data[['customerID', 'gender', 'SeniorCitizen', 'Partner']][10:15]
# Out:
#     customerID gender  SeniorCitizen Partner
# 10  9763-GRSKD   Male            NaN     Yes
# 11  7469-LKBCI   Male            NaN      No
# 12  8091-TTVAX   Male            NaN     Yes
# 13  0280-XJGEX   Male            NaN      No
# 14  5129-JLPIS   Male            NaN      No

# %%
data.iloc[10:15 , 0:4]
# Out:
#     customerID gender  SeniorCitizen Partner
# 10  9763-GRSKD   Male            NaN     Yes
# 11  7469-LKBCI   Male            NaN      No
# 12  8091-TTVAX   Male            NaN     Yes
# 13  0280-XJGEX   Male            NaN      No
# 14  5129-JLPIS   Male            NaN      No

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            NaN     Yes         No     NaN           No
# 1  5575-GNVDE    Male            NaN      No         No    34.0          Yes
# 2  3668-QPYBK    Male            NaN      No         No     2.0          Yes
# 3  7795-CFOCW    Male            NaN      No         No    45.0           No
# 4  9237-HQITU  Female            NaN      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.iloc[3,0]
# Out:
# '7795-CFOCW'

# %%
data.iloc[: , :5]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female            NaN     Yes         No
# 1     5575-GNVDE    Male            NaN      No         No
# 2     3668-QPYBK    Male            NaN      No         No
# 3     7795-CFOCW    Male            NaN      No         No
# 4     9237-HQITU  Female            NaN      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes
# 7039  2234-XADUH  Female            0.0     Yes        Yes
# 7040  4801-JZAZL  Female            0.0     Yes        Yes
# 7041  8361-LTMKD    Male            1.0     Yes         No
# 7042  3186-AJIEK    Male            0.0      No         No
#
# [7043 rows x 5 columns]

# %%
data.loc[:10 , ["gender" , "tenure" , "Churn"]]
# Out:
#     gender  tenure Churn
# 0   Female     NaN    No
# 1     Male    34.0    No
# 2     Male     2.0   Yes
# 3     Male    45.0    No
# 4   Female     2.0   Yes
# 5   Female     8.0   Yes
# 6     Male    22.0    No
# 7   Female    10.0    No
# 8   Female    28.0   Yes
# 9     Male    62.0    No
# 10    Male    13.0    No

# %%
data.loc[1500 : 1510 , ["gender" , "tenure" , "Churn"]]
# Out:
#       gender  tenure Churn
# 1500  Female    37.0    No
# 1501    Male    13.0    No
# 1502    Male    49.0    No
# 1503  Female    45.0    No
# 1504  Female    18.0    No
# 1505    Male     NaN   Yes
# 1506    Male    68.0    No
# 1507    Male    54.0    No
# 1508  Female    23.0    No
# 1509    Male    17.0   Yes
# 1510    Male    71.0    No

# %%
data.iloc[1500 : 1510 , [2,5,7,8,9]]
# Out:
#       SeniorCitizen  tenure     MultipleLines InternetService  \
# 1500            0.0    37.0  No phone service             DSL
# 1501            0.0    13.0                No              No
# 1502            0.0    49.0               Yes             DSL
# 1503            1.0    45.0               Yes     Fiber optic
# 1504            0.0    18.0                No     Fiber optic
# 1505            1.0     NaN               Yes     Fiber optic
# 1506            0.0    68.0  No phone service             DSL
# 1507            0.0    54.0                No              No
# 1508            1.0    23.0                No     Fiber optic
# 1509            0.0    17.0                No     Fiber optic
#
#            OnlineSecurity
# 1500                   No
# 1501  No internet service
# 1502                  Yes
# 1503                   No
# 1504                   No
# 1505                   No
# 1506                  Yes
# 1507  No internet service
# 1508                   No
# ...

# %% [markdown]
# ## Condition

# %%
data[data["gender"] == "Male"]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male            NaN      No         No    34.0
# 2     3668-QPYBK   Male            NaN      No         No     2.0
# 3     7795-CFOCW   Male            NaN      No         No    45.0
# 6     1452-KIOVK   Male            NaN      No        Yes    22.0
# 9     6388-TABGU   Male            NaN      No        Yes    62.0
# ...          ...    ...            ...     ...        ...     ...
# 7033  9767-FFLEM   Male            0.0      No         No    38.0
# 7035  8456-QDAVC   Male            0.0      No         No    19.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
# 7041  8361-LTMKD   Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK   Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
data[(data['gender'] == "Male") & (data['Churn']== "No")]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male            NaN      No         No    34.0
# 3     7795-CFOCW   Male            NaN      No         No    45.0
# 6     1452-KIOVK   Male            NaN      No        Yes    22.0
# 9     6388-TABGU   Male            NaN      No        Yes    62.0
# 10    9763-GRSKD   Male            NaN     Yes        Yes    13.0
# ...          ...    ...            ...     ...        ...     ...
# 7031  3605-JISKB   Male            1.0     Yes         No    55.0
# 7033  9767-FFLEM   Male            0.0      No         No    38.0
# 7035  8456-QDAVC   Male            0.0      No         No    19.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
# 7042  3186-AJIEK   Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
data[(data['gender'] == "Male") & (data['Churn']== "No") & (data["Partner"]== "Yes")]
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 10    9763-GRSKD   Male            NaN     Yes        Yes    13.0
# 12    8091-TTVAX   Male            NaN     Yes         No    58.0
# 21    1680-VDCWW   Male            NaN     Yes         No    12.0
# 24    6322-HRPFA   Male            NaN     Yes        Yes    49.0
# 28    5248-YGIJN   Male            NaN     Yes         No    72.0
# ...          ...    ...            ...     ...        ...     ...
# 7015  0666-UXTJO   Male            1.0     Yes         No    34.0
# 7020  9837-FWLCH   Male            0.0     Yes        Yes    12.0
# 7024  7398-LXGYX   Male            0.0     Yes         No    44.0
# 7031  3605-JISKB   Male            1.0     Yes         No    55.0
# 7038  6840-RESVB   Male            0.0     Yes        Yes    24.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 10            Yes            No             DSL                  Yes  ...
# ...

# %%
y = data[(data['gender'] == "Male") & (data['Churn']== "No") & (data["Partner"]== "Yes")]

# %%
y.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    1358.000000  1356.000000     1364.000000   1364.000000
# mean        0.153166    46.100295       65.695784   3231.077089
# std         0.360281    22.315622       31.106896   2403.113728
# min         0.000000     1.000000       18.800000     18.800000
# 25%         0.000000    28.000000       29.900000   1158.650000
# 50%         0.000000    51.000000       70.950000   2683.775000
# 75%         0.000000    67.000000       91.212500   5264.312500
# max         1.000000    72.000000      116.950000   8594.400000

# %% [markdown]
#  ## drop

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.drop('customerID' , axis = 1)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            NaN     Yes         No     NaN           No
# 1       Male            NaN      No         No    34.0          Yes
# 2       Male            NaN      No         No     2.0          Yes
# 3       Male            NaN      No         No    45.0           No
# 4     Female            NaN      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male            0.0     Yes        Yes    24.0          Yes
# 7039  Female            0.0     Yes        Yes    72.0          Yes
# 7040  Female            0.0     Yes        Yes    11.0           No
# 7041    Male            1.0     Yes         No     4.0          Yes
# 7042    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df = data.copy()

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop("customerID" , axis = 1 , inplace = True )

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            NaN     Yes         No     NaN           No
# 1       Male            NaN      No         No    34.0          Yes
# 2       Male            NaN      No         No     2.0          Yes
# 3       Male            NaN      No         No    45.0           No
# 4     Female            NaN      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male            0.0     Yes        Yes    24.0          Yes
# 7039  Female            0.0     Yes        Yes    72.0          Yes
# 7040  Female            0.0     Yes        Yes    11.0           No
# 7041    Male            1.0     Yes         No     4.0          Yes
# 7042    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df = data.copy()

# %%
df = data[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']]

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            NaN     Yes         No     NaN           No
# 1       Male            NaN      No         No    34.0          Yes
# 2       Male            NaN      No         No     2.0          Yes
# 3       Male            NaN      No         No    45.0           No
# 4     Female            NaN      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male            0.0     Yes        Yes    24.0          Yes
# 7039  Female            0.0     Yes        Yes    72.0          Yes
# 7040  Female            0.0     Yes        Yes    11.0           No
# 7041    Male            1.0     Yes         No     4.0          Yes
# 7042    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df = data.copy()

# %%
df2 = data.drop("customerID" , axis = 1 )

# %%
df2
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            NaN     Yes         No     NaN           No
# 1       Male            NaN      No         No    34.0          Yes
# 2       Male            NaN      No         No     2.0          Yes
# 3       Male            NaN      No         No    45.0           No
# 4     Female            NaN      No         No     2.0          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male            0.0     Yes        Yes    24.0          Yes
# 7039  Female            0.0     Yes        Yes    72.0          Yes
# 7040  Female            0.0     Yes        Yes    11.0           No
# 7041    Male            1.0     Yes         No     4.0          Yes
# 7042    Male            0.0      No         No    66.0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
data.drop(5)  #row
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            NaN     Yes         No     NaN
# 1     5575-GNVDE    Male            NaN      No         No    34.0
# 2     3668-QPYBK    Male            NaN      No         No     2.0
# 3     7795-CFOCW    Male            NaN      No         No    45.0
# 4     9237-HQITU  Female            NaN      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.013521        0.221101      0.102831
# tenure               0.013521  1.000000        0.238635      0.822171
# MonthlyCharges       0.221101  0.238635        1.000000      0.650468
# TotalCharges         0.102831  0.822171        0.650468      1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
data['gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
data['gender'].replace("Male" , 0 , inplace = True)
data['gender'].replace("Female" , 1 , inplace = True)

# %%
data['gender'].value_counts()
# Out:
# 0    3555
# 1    3488
# Name: gender, dtype: int64

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
#  ## Groupby

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df = data.groupby(["Churn" , "Partner" , "Dependents"]).mean()

# %%
df
# Out:
#                             gender  SeniorCitizen     tenure  MonthlyCharges  \
# Churn Partner Dependents
# No    No      No          0.495132       0.132929  29.094991       58.359295
#               Yes         0.394366       0.021352  27.615942       49.012676
#       Yes     No          0.501217       0.254279  47.931763       72.398500
#               Yes         0.500667       0.042225  44.568733       58.611867
# Yes   No      No          0.522707       0.247534  13.918002       71.866118
#               Yes         0.428571       0.026316  13.942857       65.396104
#       Yes     No          0.445238       0.424821  28.050847       82.549643
#               Yes         0.530120       0.081301  25.285714       75.176104
#
#                           TotalCharges
# Churn Partner Dependents
# No    No      No           1876.131108
#               Yes          1474.107218
#       Yes     No           3636.103001
#               Yes          2846.387900
# ...

# %%
y = data.groupby(['InternetService'])

# %%
y

# %%
y.mean()
# Out:
#                    gender  SeniorCitizen     tenure  MonthlyCharges  \
# InternetService
# DSL              0.490706       0.107872  33.577167       58.102169
# Fiber optic      0.501615       0.269893  33.378113       91.500129
# No               0.489515       0.034211  31.490196       21.079194
#
#                  TotalCharges
# InternetService
# DSL               2120.126952
# Fiber optic       3205.304570
# No                 671.582372
